# %% [markdown]
# # План домашних заданий

# %% [markdown]
# - Описание задачи и знакомство с данными
# - Домашнее задание 1. Генерация и фильтрация признаков
# - Домашнее задание 2. Прогноз времени и вида поломки машин, настройка ML-модели
# - Дополнительное задание. Визуализация прогнозов, ошибок модели и важности признаков
# - Домашнее задание 3. Оптимизация. Тюнинг гиперпараметров с помощью `Optuna`
# - Домашнее задание 4. Блендинг
# - Домашнее задание 5. Парсинг внешних данных и оптимизация памяти
# - Отправка финального решения на лидерборд на Kaggle

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # <center id="part0"> Описание задачи

# %% [markdown]
# **Предыстория:**  мы работаем с каршеринговой компанией, которая управляет крупным автопарком машин. Наша цель — предотвратить длительные периоды простоя машин из-за поломок через своевременное обслуживание и ремонт.
#
#
# **Идея для решения проблемы:** создать приоритизированный список обхода машин. Этот список поможет технической бригаде сосредоточиться на автомобилях, которые наиболее вероятно выйдут из строя в ближайшее время.
#
#
# **Как компания решает задачу:**
#
# * Собирает данные о поездках и состоянии машин до поломок.
#
# * Нанимает Data Scientist, чтобы он смог использовать эти данные для анализа и прогнозирования характера поломок.
#
# **Важный момент**: задачи этого специалиста (Data Scientist) предстоит выполнять вам.

# %% [markdown]
# ## <center> Знакомство с данными

# %% [markdown]
# ### Информация про машины с таргетом (основной датасет)

# %%
car_train = pd.read_csv('https://raw.githubusercontent.com/a-milenkin/Competitive_Data_Science/main/data/car_train.csv')
car_train.sample(5)
# Out:
#           car_id            model  car_type fuel_type  car_rating  \
# 1010  q12145655O      Skoda Rapid   economy    petrol        4.18
# 1796  U-1298358e  Hyundai Solaris   economy    petrol        5.02
# 618   W-1949796N   Nissan Qashqai  standart    petrol        4.12
# 377   p22837387w        VW Tiguan   economy    petrol        3.76
# 2007  M10208049m          Audi A4   premium    petrol        4.26
#
#       year_to_start  riders  year_to_work  target_reg     target_class
# 1010           2017  117974          2015       29.75  engine_overheat
# 1796           2014   70581          2018       35.65      engine_fuel
# 618            2013   43877          2016       30.80  engine_overheat
# 377            2017  131667          2017       24.26      engine_fuel
# 2007           2017  109507          2019       63.82  engine_overheat

# %% [markdown]
# - `car_id` — идентификатор машины
# - `model` / `car_type` / `fuel_type` — марка, класс и тип топлива машины
# - `car_rating` / `riders` — общий рейтинг и общее число поездок к концу 2021 года
# - `year_to_start` / `year_to_work` — год выпуска машины и год начала работы в автопарке
# - `target_reg` — количество дней до поломки
# - `target_class` — класс поломки (всего 9 видов)

# %% [markdown]
# ### Информация про поездки

# %%
rides_info = pd.read_csv('https://raw.githubusercontent.com/a-milenkin/Competitive_Data_Science/main/data/rides_info.csv')
rides_info.sample(5)
# Out:
#            user_id      car_id ride_id   ride_date  rating  ride_duration  \
# 231302  H11434748M  Q-2259244S     b1p  2020-01-30   10.00             46
# 389293  C20024510R  b12102660G     u1M  2020-01-30    3.26             13
# 23261   d18231683N  B13169162p     P1v  2020-03-04    4.13             55
# 689514  D32465922h  w-8712305w     t1e  2020-03-08    6.55             12
# 497735  I21795865k  j-1317678J     w1u  2020-02-20    5.12             21
#
#         ride_cost  speed_avg   speed_max  stop_times     distance  refueling  \
# 231302        547         49   55.000000           0  2294.962285          0
# 389293        178         37   62.000000           1   392.244018          0
# 23261         655         54  114.000000           1  2305.117286          0
# 689514        151         42  138.000000           1   454.990308          0
# 497735        245         49   83.516247           0   796.436666          0
#
#         user_ride_quality  deviation_normal
# 231302           8.458220            -0.000
# 389293           2.471396            19.227
# 23261            3.441090            -4.079
# 689514          29.662635            -3.073
# 497735           4.400269            -3.962

# %% [markdown]
# - `user_id` / `car_id` / `ride_id` — идентификаторы водителя, машины, поездки соответственно
# - `ride_date` / `rating` — дата поездки и рейтинг, поставленный водителем
# - `ride_duration` / `distance` / `ride_cost` —  длительность (время),  пройденное расстояние, стоимость поездки
# - `speed_avg` / `speed_max` — средняя и максимальная скорости поездки соответственно
# - `stop_times` / `refueling` — количество остановок (паузы) и флаг: была ли дозаправка
# - `user_ride_quality` — оценка манеры вождения водителя машины, определенная скоринговой ML-системой сервиса
# - `deviation_normal` — общий показатель датчиков о состоянии машины, относительно эталонных показателей (нормы)

# %% [markdown]
# ### Информация про водителей

# %%
driver_info = pd.read_csv('https://raw.githubusercontent.com/a-milenkin/Competitive_Data_Science/main/data/driver_info.csv')
driver_info.sample(5)
# Out:
#        age  user_rating  user_rides  user_time_accident     user_id  sex  \
# 4606    34          7.4         638                 8.0  f41834419Q    0
# 11672   36          8.2        1677                 7.0  k56817562H    0
# 10607   31          9.3        1001                18.0  E19886650r    1
# 2869    24          8.2        1873                 7.0  I73892988G    1
# 166     37          7.9        2031                 4.0  Y21918575C    1
#
#       first_ride_date
# 4606        2019-5-28
# 11672       2021-7-24
# 10607       2020-11-4
# 2869        2018-4-12
# 166          2018-3-2

# %% [markdown]
# - `user_id` / `age` / `sex` — идентификатор, возраст и пол водителя, соответственно
# - `user_rating` — общий рейтинг пользователя за все поездки к концу 2021 года
# - `user_rides` — общее количество поездок к концу 2021 года
# - `user_time_accident` — число инцидентов (это могли быть аварии/штрафы/эвакуация машины)
# - `first_ride_date` — дата первой поездки

# %% [markdown]
# ### Информация про ремонт машин

# %%
fix_info = pd.read_csv('https://raw.githubusercontent.com/a-milenkin/Competitive_Data_Science/main/data/fix_info.csv')
fix_info.sample(5)
# Out:
#             car_id worker_id         fix_date  work_type  destroy_degree  \
# 35855   t-2297441l        MF   2019-5-20 11:9     repair             4.9
# 41722   p-1077837n        MV   2019-8-17 0:37  reparking             1.0
# 101631  H-2108091L        KX  2020-6-22 22:27     repair            10.0
# 6281    d-2251789J        QV  2019-9-15 16:16  reparking             1.0
# 33577   C17311656B        EP  2018-7-11 14:14  reparking             1.0
#
#         work_duration
# 35855               9
# 41722              19
# 101631             48
# 6281               28
# 33577              35

# %% [markdown]
# - `worker_id` / `car_id` — идентификатор работника и машины
# - `work_type` / `work_duration` — тип и длительность (в часах) проводимой работы
# - `destroy_degree` — степень износа/поврежденности машины в случае поломки
# - `fix_date` — время начала ремонта (снятия машины с линии)

# %% [markdown]
# # Домашнее задание 1. Генерация и фильтрация признаков

# %% [markdown]
# <center> <img src="https://ucarecdn.com/bf4c772d-b67a-42ae-a48b-cfd83910b0a2/" width=700>

# %% [markdown]
# <div class="alert alert-info">
#
# **Цель блока** — сгенерировать признаки из дополнительных датасетов и добавить их к основному датасету, произвести фильтрацию признаков.

# %% [markdown]
#
# ## Задание 1. Генерация признаков из дополнительных датасетов (6 баллов)

# %% [markdown]
# <div class="alert alert-info">
#
# 1. Возьмите датасет `rides_info` с информацией о поездках и проведите группировку по каждой машине отдельно.
#
# 2. Для каждой машины (то есть для каждого `car_id`) подсчитайте несколько признаков:
#   - минимальный рейтинг за все поездки;
#   - средний рейтинг за все поездки;
#   - общее количество километров, которое машина проехала;
#   - максимальная скорость;
#   - общее количество поездок для каждой машины.
#
# 3. Добавьте минимум 3 признака на свой выбор.
#
# 4. Сделайте соединение таблиц — вспомните про методы соединения и выберите подходящий для этого случая.
#
# 5. Подключите информацию про водителей (`driver_info`) и про ремонт машин (`fix_info`). Добавьте минимум 3 любых признака с каждого датасета.
#
#
# <h4> Критерии оценивания </h4>
#
# - Добавлены 5 обязательных и минимум 3 любых признака из датасета `rides_info` — 2 балла.
# - Добавлены минимум 3 любых признака из датасета `driver_info` — 2 балла.
# - Добавлены минимум 3 любых признака из датасета `fix_info` — 2 балла.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# <h4> Советы по Feature Engineering</h4>
#
# - Начинайте с сырых данных.
# - Используйте все доступные данные. Покрывайте признаками всю имеющуюся информацию в данных.
# - Формулируйте предположения: от чего зависит таргет?
# - Смотрите визуально на классы/ошибки и делайте предположения. Какие полезны?
# - Помните, что слишком много признаков может быть вредно. Потом придется отфильтровывать.
#
# <h4> Полезные источники </h4>
#
# - Занятие про Feature Engineering.
# - Занятие про Feature Selection.
# - [Max Kuhn and Kjell Johnson. Feature Engineering and Selection: A Practical Approach for Predictive Models](http://www.feat.engineering/).

# %% [markdown]
# ### Пример расчета признака

# %%
# Пример расчета одного признака
rides_info.groupby('car_id', as_index=False).agg(
    mean_rating = ('rating', 'mean'),
    # ... еще признаки
)

df = pd.merge(...) # Соедините полученный датасет с фичами с основным датасетом

# YOUR CODE HERE
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 7
#       1 # Пример расчета одного признака
#       2 rides_info.groupby('car_id', as_index=False).agg(
#       3     mean_rating = ('rating', 'mean'),
#       4     # ... еще признаки
#       5 )
# ----> 7 df = pd.merge(...) # Соедините полученный датасет с фичами с основным датасетом
#       9 # YOUR CODE HERE
#
# TypeError: merge() missing 1 required positional argument: 'right'

# %% [markdown]
# ### Идеи для новых признаков
#
# 1.   Новый пункт
# 2.   Новый пункт

# %% [markdown]
# * `feature_min_max_diff` — разница между максимальным и минимальным значениями `deviation_normal` для каждой машины
# * `feature_corner` — угол наклона по признаку `user_ride_quality` для каждой машины
# * `feature_mean` — среднее значение `deviation_normal` для каждой машины
# * `feature_shift` — точка перегиба/сдвига для `deviation_normal`
# * `feature_start` — значение точки старта для `deviation_normal`
# * `feature_nans` — сумма пропусков для столбца `...` для каждой машины
# * `feature_quant` — `X %` квантиль для столбца `...` для каждой машины
#
# Подумайте, какие из признаков могут оказаться самыми полезными?

# %% [markdown]
# # РЕШЕНИЕ: вспомогательная логика

# %%
def check_data_distribution(df, threshold = 1e+12):
    df.info()
    print(f'Размерность: {df.shape}')

    numeric_dataset = df.select_dtypes(include=[np.number, 'float32', 'float64', 'Int64', 'int64', 'int32', 'int8'])

    # проверить inf
    columns_with_inf = []

    for column in numeric_dataset:
        if np.isinf(numeric_dataset[column]).any():
            columns_with_inf.append(column)

    print(f'Кол-во признаков с Infinite Values: {len(columns_with_inf)}')

    # проверить na
    total_nan = df.isnull().sum().sum()

    print(f'Кол-во Nan: {total_nan}')

    # проверить модуль, макс и мин
    abs_max_in_columns = numeric_dataset.abs().max()

    excessively_large_values_in_columns = abs_max_in_columns[abs_max_in_columns > threshold].index
    print("Признаки с большими значениями по модулю:", excessively_large_values_in_columns)

    min_value = numeric_dataset.min().min()
    max_value = numeric_dataset.max().max()

    print("Минимум набора:", min_value)
    print("Максимум набора:", max_value)

    # проверить дубликаты
    print(f'Дубликаты в рядах: {any(df.duplicated())}')
    print(f'Дубликаты в столбцах: {any(df.columns.duplicated())}')

    # проверить неинформативные признаки
    print(f'Неинформативные признаки: {[col for col in numeric_dataset if df[col].nunique() == 1]}')


def analyze_dataset_columns(dataset):
    for col in dataset.columns:
        print(f"~Уникальные значения для столбца {col}~: {dataset[col].nunique()}")
        print(f"~Кол-во дубликатов для столбца {col}~: {dataset[col].duplicated().sum()}")
        print(f"~Первые 3 val counts для столбца {col}~:")
        print(dataset[col].value_counts().head(3))
        print(f"~Кол-во пропущенных значений для столбца {col}~: {dataset[col].isna().sum()}")

def get_group_duplicates(dataset, features):
    subset_duplicates = dataset.duplicated(subset=features).sum()
    print(f"~Кол-во дубликатов для столбцов {', '.join(features)}~: {subset_duplicates}")

# %%
check_data_distribution(rides_info)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 739500 entries, 0 to 739499
# Data columns (total 14 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   user_id            739500 non-null  object
#  1   car_id             739500 non-null  object
#  2   ride_id            739500 non-null  object
#  3   ride_date          739500 non-null  object
#  4   rating             739500 non-null  float64
#  5   ride_duration      739500 non-null  int64
#  6   ride_cost          739500 non-null  int64
#  7   speed_avg          739500 non-null  int64
#  8   speed_max          736139 non-null  float64
#  9   stop_times         739500 non-null  int64
#  10  distance           739500 non-null  float64
#  11  refueling          739500 non-null  int64
#  12  user_ride_quality  736872 non-null  float64
#  13  deviation_normal   739500 non-null  float64
# dtypes: float64(5), int64(5), object(4)
# memory usage: 79.0+ MB
# Размерность: (739500, 14)
# Кол-во признаков с Infinite Values: 0
# Кол-во Nan: 5989
# Признаки с большими значениями по модулю: Index([], dtype='object')
# Минимум набора: -126.883
# Максимум набора: 3606050.57821893
# Дубликаты в рядах: False
# Дубликаты в столбцах: False
# Неинформативные признаки: []

# %%
analyze_dataset_columns(rides_info)
# Out:
# ~Уникальные значения для столбца user_id~: 15153
# ~Кол-во дубликатов для столбца user_id~: 724347
# ~Первые 3 val counts для столбца user_id~:
# n50223955s    153
# I27349458O    149
# W13073879n    149
# Name: user_id, dtype: int64
# ~Кол-во пропущенных значений для столбца user_id~: 0
# ~Уникальные значения для столбца car_id~: 4250
# ~Кол-во дубликатов для столбца car_id~: 735250
# ~Первые 3 val counts для столбца car_id~:
# A-1049127W    174
# i30546413z    174
# i17810499T    174
# Name: car_id, dtype: int64
# ~Кол-во пропущенных значений для столбца car_id~: 0
# ~Уникальные значения для столбца ride_id~: 2704
# ~Кол-во дубликатов для столбца ride_id~: 736796
# ~Первые 3 val counts для столбца ride_id~:
# k1y    330
# V1C    329
# l1j    326
# Name: ride_id, dtype: int64
# ~Кол-во пропущенных значений для столбца ride_id~: 0
# ~Уникальные значения для столбца ride_date~: 93
# ~Кол-во дубликатов для столбца ride_date~: 739407
# ~Первые 3 val counts для столбца ride_date~:
# 2020-01-01    8039
# 2020-01-31    8039
# 2020-03-02    8039
# Name: ride_date, dtype: int64
# ~Кол-во пропущенных значений для столбца ride_date~: 0
# ~Уникальные значения для столбца rating~: 1001
# ~Кол-во дубликатов для столбца rating~: 738499
# ~Первые 3 val counts для столбца rating~:
# 0.1     17086
# 10.0     4422
# 0.0      4368
# Name: rating, dtype: int64
# ~Кол-во пропущенных значений для столбца rating~: 0
# ~Уникальные значения для столбца ride_duration~: 31651
# ~Кол-во дубликатов для столбца ride_duration~: 707849
# ~Первые 3 val counts для столбца ride_duration~:
# 49    11473
# 46    11377
# 47    11293
# Name: ride_duration, dtype: int64
# ~Кол-во пропущенных значений для столбца ride_duration~: 0
# ~Уникальные значения для столбца ride_cost~: 65021
# ~Кол-во дубликатов для столбца ride_cost~: 674479
# ~Первые 3 val counts для столбца ride_cost~:
# 346    2359
# 345    2219
# 475    2192
# Name: ride_cost, dtype: int64
# ~Кол-во пропущенных значений для столбца ride_cost~: 0
# ~Уникальные значения для столбца speed_avg~: 76
# ~Кол-во дубликатов для столбца speed_avg~: 739424
# ~Первые 3 val counts для столбца speed_avg~:
# 51    29032
# 50    28909
# 49    28722
# Name: speed_avg, dtype: int64
# ~Кол-во пропущенных значений для столбца speed_avg~: 0
# ~Уникальные значения для столбца speed_max~: 261673
# ~Кол-во дубликатов для столбца speed_max~: 477826
# ~Первые 3 val counts для столбца speed_max~:
# 67.0    12789
# 68.0    12746
# 70.0    12741
# Name: speed_max, dtype: int64
# ~Кол-во пропущенных значений для столбца speed_max~: 3361
# ~Уникальные значения для столбца stop_times~: 24
# ~Кол-во дубликатов для столбца stop_times~: 739476
# ~Первые 3 val counts для столбца stop_times~:
# 0    290678
# 1    259423
# 2    117298
# Name: stop_times, dtype: int64
# ~Кол-во пропущенных значений для столбца stop_times~: 0
# ~Уникальные значения для столбца distance~: 739500
# ~Кол-во дубликатов для столбца distance~: 0
# ~Первые 3 val counts для столбца distance~:
# 514.246920     1
# 1359.720744    1
# 1356.187626    1
# Name: distance, dtype: int64
# ~Кол-во пропущенных значений для столбца distance~: 0
# ~Уникальные значения для столбца refueling~: 2
# ~Кол-во дубликатов для столбца refueling~: 739498
# ~Первые 3 val counts для столбца refueling~:
# 0    739497
# 1         3
# Name: refueling, dtype: int64
# ~Кол-во пропущенных значений для столбца refueling~: 0
# ~Уникальные значения для столбца user_ride_quality~: 736872
# ~Кол-во дубликатов для столбца user_ride_quality~: 2627
# ~Первые 3 val counts для столбца user_ride_quality~:
# 1.115260     1
# 26.010609    1
# 21.882209    1
# Name: user_ride_quality, dtype: int64
# ~Кол-во пропущенных значений для столбца user_ride_quality~: 2628
# ~Уникальные значения для столбца deviation_normal~: 108357
# ~Кол-во дубликатов для столбца deviation_normal~: 631143
# ~Первые 3 val counts для столбца deviation_normal~:
# -0.000    47158
#  0.001    16233
# -0.001    13817
# Name: deviation_normal, dtype: int64
# ~Кол-во пропущенных значений для столбца deviation_normal~: 0

# %%
get_group_duplicates(rides_info, ['car_id', 'ride_id', 'user_id'])
# Out:
# ~Кол-во дубликатов для столбцов car_id, ride_id, user_id~: 0

# %%
get_group_duplicates(rides_info, ['car_id', 'ride_id'])
# Out:
# ~Кол-во дубликатов для столбцов car_id, ride_id~: 23152

# %%
rides_info.sort_values(by=['ride_id']).head(5)
# Out:
#            user_id      car_id ride_id   ride_date  rating  ride_duration  \
# 300570  L10406820V  V-2042242Z     A1A  2020-02-08    1.51             35
# 706224  g17416818c  x38176093d     A1A  2020-03-11    2.41            105
# 616659  R48112572R  r16294059S     A1A  2020-01-03    9.22             21
# 393122  A17826012p  b35718807I     A1A  2020-01-30    7.13          12719
# 357289  i29678357d  Z16406378j     A1A  2020-02-05    5.72             30
#
#         ride_cost  speed_avg   speed_max  stop_times       distance  \
# 300570        487         31   68.000000           0    1146.081312
# 706224        775         89  144.023173           0    3719.312403
# 616659        249         36   51.000000           1     624.416040
# 393122     101747         39   75.000000           1  504300.062724
# 357289        296         43   73.000000           1     554.429170
#
#         refueling  user_ride_quality  deviation_normal
# 300570          0          -0.722598           -19.988
# 706224          0         -10.194232             0.042
# 616659          0          -0.401222             0.494
# 393122          0          13.026031             7.629
# 357289          0           1.488879           -11.979

# %%
rides_info.sort_values(by=['ride_id']).head(5)
# Out:
#            user_id      car_id ride_id   ride_date  rating  ride_duration  \
# 300570  L10406820V  V-2042242Z     A1A  2020-02-08    1.51             35
# 706224  g17416818c  x38176093d     A1A  2020-03-11    2.41            105
# 616659  R48112572R  r16294059S     A1A  2020-01-03    9.22             21
# 393122  A17826012p  b35718807I     A1A  2020-01-30    7.13          12719
# 357289  i29678357d  Z16406378j     A1A  2020-02-05    5.72             30
#
#         ride_cost  speed_avg   speed_max  stop_times       distance  \
# 300570        487         31   68.000000           0    1146.081312
# 706224        775         89  144.023173           0    3719.312403
# 616659        249         36   51.000000           1     624.416040
# 393122     101747         39   75.000000           1  504300.062724
# 357289        296         43   73.000000           1     554.429170
#
#         refueling  user_ride_quality  deviation_normal
# 300570          0          -0.722598           -19.988
# 706224          0         -10.194232             0.042
# 616659          0          -0.401222             0.494
# 393122          0          13.026031             7.629
# 357289          0           1.488879           -11.979

# %% [markdown]
# # РЕШЕНИЕ: Задание 1. Генерация признаков
# *Пункты 1,2,3,4,5*
#
# Возьмите датасет rides_info с информацией о поездках и проведите группировку по каждой машине отдельно.
# Для каждой машины (то есть для каждого car_id) подсчитайте несколько признаков:
#
#     минимальный рейтинг за все поездки;
#     средний рейтинг за все поездки;
#     общее количество километров, которое машина проехала;
#     максимальная скорость;
#     общее количество поездок для каждой машины.
#
# Добавьте минимум 3 признака на свой выбор.
# Сделайте соединение таблиц — вспомните про методы соединения и выберите подходящий для этого случая.
# Подключите информацию про водителей (driver_info) и про ремонт машин (fix_info). Добавьте минимум 3 любых признака с каждого датасета.

# %%
def aggregate_rides_info(rides_info_df, driver_info_df):
    # объединим с driver info
    merged_df = pd.merge(rides_info_df, driver_info_df, on='user_id', how='left')

    aggregated_df = merged_df.groupby('car_id').agg(
        min_rating=('rating', 'min'),
        avg_rating=('rating', 'mean'),
        total_distance=('distance', 'sum'),
        max_speed=('speed_max', 'max'),
        total_rides=('car_id', 'size'),
        sum_user_rides=('user_rides', 'sum'),  # 1й новый признак из driver_info
        sum_user_time_accident=('user_time_accident', 'sum'),  # 2й новый признак из driver_info
        mean_user_time_accident=('user_time_accident', 'mean'),  # 3й новый признак из driver_info
        deviation_normal_mean=('deviation_normal', 'mean'), # 1й новый признак из rides_info
        deviation_normalmin_max_diff=('deviation_normal', lambda x: x.max() - x.min()), # 2й новый признак из rides_info
    ).reset_index()

    threshold = merged_df['deviation_normal'].quantile(0.75)
    counts_above_threshold = merged_df[merged_df['deviation_normal'] > threshold].groupby('car_id').size().reset_index(name='count_above_75th') # 3й новый признак из rides_info

    # Merge the counts above threshold back into the aggregated data
    final_df = pd.merge(aggregated_df, counts_above_threshold, on='car_id', how='left')
    final_df['count_above_75th'] = final_df['count_above_75th'].fillna(0)

    return final_df

# %%
rides_driver_info_merged_agg = aggregate_rides_info(rides_info, driver_info)

# %%
rides_driver_info_merged_agg.head(10)
# Out:
#        car_id  min_rating  avg_rating  total_distance   max_speed  \
# 0  A-1049127W        0.10    4.255172    1.125753e+07  179.729652
# 1  A-1079539w        0.10    4.088046    1.912765e+07  184.505566
# 2  A-1162143G        0.10    4.662299    2.995194e+06  180.000000
# 3  A-1228282M        0.10    4.225172    1.793685e+07  182.446070
# 4  A-1339912r        0.10    4.690115    1.202552e+07  152.000000
# 5  A-1463575c        0.10    4.510805    1.681067e+07  161.000000
# 6  A-1680490U        0.96    5.453736    1.526994e+07  109.355027
# 7  A-1683178f        0.10    4.337299    2.130874e+07  177.034172
# 8  A-1721538a        0.10    5.606207    1.674416e+07  112.927322
# 9  A-1737634s        0.10    4.347701    1.104011e+07  104.658255
#
#    total_rides  sum_user_rides  sum_user_time_accident  \
# 0          174          146833                  1618.0
# 1          174          153870                  1559.0
# 2          174          148344                  2217.0
# 3          174          158618                  1381.0
# 4          174          139218                  2112.0
# 5          174          154631                  1998.0
# 6          174          151106                  1430.0
# 7          174          151988                  1751.0
# 8          174          151236                  1414.0
# 9          174          164187                  1453.0
#
#    mean_user_time_accident  deviation_normal_mean  \
# 0                 9.298851              -6.136672
# 1                 8.959770              47.443270
# 2                17.736000              10.556425
# 3                 7.936782               9.810747
# 4                18.051282              22.965937
# 5                17.224138              -2.293339
# 6                 8.218391              -6.998305
# 7                15.226087               9.955155
# 8                 8.126437              -2.003155
# 9                 8.350575             -18.673575
#
#    deviation_normalmin_max_diff  count_above_75th
# 0                        31.688               0.0
# 1                        74.349             168.0
# 2                        46.177             113.0
# 3                        64.898              84.0
# 4                        40.142             162.0
# 5                        13.900               0.0
# 6                        28.998               0.0
# 7                        52.401              91.0
# 8                         8.301               0.0
# 9                        68.741               4.0

# %%
check_data_distribution(rides_driver_info_merged_agg)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4250 entries, 0 to 4249
# Data columns (total 12 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   car_id                        4250 non-null   object
#  1   min_rating                    4250 non-null   float64
#  2   avg_rating                    4250 non-null   float64
#  3   total_distance                4250 non-null   float64
#  4   max_speed                     4250 non-null   float64
#  5   total_rides                   4250 non-null   int64
#  6   sum_user_rides                4250 non-null   int64
#  7   sum_user_time_accident        4250 non-null   float64
#  8   mean_user_time_accident       4250 non-null   float64
#  9   deviation_normal_mean         4250 non-null   float64
#  10  deviation_normalmin_max_diff  4250 non-null   float64
#  11  count_above_75th              4250 non-null   float64
# dtypes: float64(9), int64(2), object(1)
# memory usage: 431.6+ KB
# Размерность: (4250, 12)
# Кол-во признаков с Infinite Values: 0
# Кол-во Nan: 0
# Признаки с большими значениями по модулю: Index([], dtype='object')
# Минимум набора: -67.43761494252874
# Максимум набора: 32563653.0931651
# Дубликаты в рядах: False
# Дубликаты в столбцах: False
# Неинформативные признаки: ['total_rides']

# %%
analyze_dataset_columns(rides_driver_info_merged_agg)
# Out:
# ~Уникальные значения для столбца car_id~: 4250
# ~Кол-во дубликатов для столбца car_id~: 0
# ~Первые 3 val counts для столбца car_id~:
# A-1049127W    1
# i30546413z    1
# i17810499T    1
# Name: car_id, dtype: int64
# ~Кол-во пропущенных значений для столбца car_id~: 0
# ~Уникальные значения для столбца min_rating~: 107
# ~Кол-во дубликатов для столбца min_rating~: 4143
# ~Первые 3 val counts для столбца min_rating~:
# 0.10    3172
# 0.00     470
# 0.19      19
# Name: min_rating, dtype: int64
# ~Кол-во пропущенных значений для столбца min_rating~: 0
# ~Уникальные значения для столбца avg_rating~: 3892
# ~Кол-во дубликатов для столбца avg_rating~: 358
# ~Первые 3 val counts для столбца avg_rating~:
# 4.416782    4
# 4.557874    4
# 4.357069    4
# Name: avg_rating, dtype: int64
# ~Кол-во пропущенных значений для столбца avg_rating~: 0
# ~Уникальные значения для столбца total_distance~: 4250
# ~Кол-во дубликатов для столбца total_distance~: 0
# ~Первые 3 val counts для столбца total_distance~:
# 1.125753e+07    1
# 8.903183e+06    1
# 1.504239e+07    1
# Name: total_distance, dtype: int64
# ~Кол-во пропущенных значений для столбца total_distance~: 0
# ~Уникальные значения для столбца max_speed~: 3495
# ~Кол-во дубликатов для столбца max_speed~: 755
# ~Первые 3 val counts для столбца max_speed~:
# 200.0    209
# 119.0     35
# 160.0     19
# Name: max_speed, dtype: int64
# ~Кол-во пропущенных значений для столбца max_speed~: 0
# ~Уникальные значения для столбца total_rides~: 1
# ~Кол-во дубликатов для столбца total_rides~: 4249
# ~Первые 3 val counts для столбца total_rides~:
# 174    4250
# Name: total_rides, dtype: int64
# ~Кол-во пропущенных значений для столбца total_rides~: 0
# ~Уникальные значения для столбца sum_user_rides~: 3989
# ~Кол-во дубликатов для столбца sum_user_rides~: 261
# ~Первые 3 val counts для столбца sum_user_rides~:
# 152877    3
# 149384    3
# 148150    3
# Name: sum_user_rides, dtype: int64
# ~Кол-во пропущенных значений для столбца sum_user_rides~: 0
# ~Уникальные значения для столбца sum_user_time_accident~: 1216
# ~Кол-во дубликатов для столбца sum_user_time_accident~: 3034
# ~Первые 3 val counts для столбца sum_user_time_accident~:
# 1268.0    16
# 1296.0    14
# 1281.0    14
# Name: sum_user_time_accident, dtype: int64
# ~Кол-во пропущенных значений для столбца sum_user_time_accident~: 0
# ~Уникальные значения для столбца mean_user_time_accident~: 2652
# ~Кол-во дубликатов для столбца mean_user_time_accident~: 1598
# ~Первые 3 val counts для столбца mean_user_time_accident~:
# 7.287356    14
# 7.551724    13
# 7.448276    13
# Name: mean_user_time_accident, dtype: int64
# ~Кол-во пропущенных значений для столбца mean_user_time_accident~: 0
# ~Уникальные значения для столбца deviation_normal_mean~: 4242
# ~Кол-во дубликатов для столбца deviation_normal_mean~: 8
# ~Первые 3 val counts для столбца deviation_normal_mean~:
# -3.324523    2
# -2.199356    2
# -4.000138    2
# Name: deviation_normal_mean, dtype: int64
# ~Кол-во пропущенных значений для столбца deviation_normal_mean~: 0
# ~Уникальные значения для столбца deviation_normalmin_max_diff~: 3616
# ~Кол-во дубликатов для столбца deviation_normalmin_max_diff~: 634
# ~Первые 3 val counts для столбца deviation_normalmin_max_diff~:
# 10.001    23
# 10.000    17
# 29.015    15
# Name: deviation_normalmin_max_diff, dtype: int64
# ~Кол-во пропущенных значений для столбца deviation_normalmin_max_diff~: 0
# ~Уникальные значения для столбца count_above_75th~: 173
# ~Кол-во дубликатов для столбца count_above_75th~: 4077
# ~Первые 3 val counts для столбца count_above_75th~:
# 0.0    1525
# 1.0      79
# 3.0      56
# Name: count_above_75th, dtype: int64
# ~Кол-во пропущенных значений для столбца count_above_75th~: 0

# %%
check_data_distribution(car_train)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2337 entries, 0 to 2336
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   car_id         2337 non-null   object
#  1   model          2337 non-null   object
#  2   car_type       2337 non-null   object
#  3   fuel_type      2337 non-null   object
#  4   car_rating     2337 non-null   float64
#  5   year_to_start  2337 non-null   int64
#  6   riders         2337 non-null   int64
#  7   year_to_work   2337 non-null   int64
#  8   target_reg     2337 non-null   float64
#  9   target_class   2337 non-null   object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 182.7+ KB
# Размерность: (2337, 10)
# Кол-во признаков с Infinite Values: 0
# Кол-во Nan: 0
# Признаки с большими значениями по модулю: Index([], dtype='object')
# Минимум набора: 0.98
# Максимум набора: 142862.0
# Дубликаты в рядах: False
# Дубликаты в столбцах: False
# Неинформативные признаки: []

# %%
analyze_dataset_columns(car_train)
# Out:
# ~Уникальные значения для столбца car_id~: 2337
# ~Кол-во дубликатов для столбца car_id~: 0
# ~Первые 3 val counts для столбца car_id~:
# y13744087j    1
# s48916749r    1
# T77801635B    1
# Name: car_id, dtype: int64
# ~Кол-во пропущенных значений для столбца car_id~: 0
# ~Уникальные значения для столбца model~: 26
# ~Кол-во дубликатов для столбца model~: 2311
# ~Первые 3 val counts для столбца model~:
# Hyundai Solaris    161
# Smart ForFour      158
# Renault Kaptur     154
# Name: model, dtype: int64
# ~Кол-во пропущенных значений для столбца model~: 0
# ~Уникальные значения для столбца car_type~: 4
# ~Кол-во дубликатов для столбца car_type~: 2333
# ~Первые 3 val counts для столбца car_type~:
# economy     1536
# standart     599
# business     117
# Name: car_type, dtype: int64
# ~Кол-во пропущенных значений для столбца car_type~: 0
# ~Уникальные значения для столбца fuel_type~: 2
# ~Кол-во дубликатов для столбца fuel_type~: 2335
# ~Первые 3 val counts для столбца fuel_type~:
# petrol     2289
# electro      48
# Name: fuel_type, dtype: int64
# ~Кол-во пропущенных значений для столбца fuel_type~: 0
# ~Уникальные значения для столбца car_rating~: 269
# ~Кол-во дубликатов для столбца car_rating~: 2068
# ~Первые 3 val counts для столбца car_rating~:
# 4.70    30
# 4.28    29
# 4.48    27
# Name: car_rating, dtype: int64
# ~Кол-во пропущенных значений для столбца car_rating~: 0
# ~Уникальные значения для столбца year_to_start~: 7
# ~Кол-во дубликатов для столбца year_to_start~: 2330
# ~Первые 3 val counts для столбца year_to_start~:
# 2015    604
# 2014    451
# 2013    433
# Name: year_to_start, dtype: int64
# ~Кол-во пропущенных значений для столбца year_to_start~: 0
# ~Уникальные значения для столбца riders~: 2306
# ~Кол-во дубликатов для столбца riders~: 31
# ~Первые 3 val counts для столбца riders~:
# 44425    2
# 86195    2
# 20727    2
# Name: riders, dtype: int64
# ~Кол-во пропущенных значений для столбца riders~: 0
# ~Уникальные значения для столбца year_to_work~: 9
# ~Кол-во дубликатов для столбца year_to_work~: 2328
# ~Первые 3 val counts для столбца year_to_work~:
# 2019    346
# 2018    337
# 2020    336
# Name: year_to_work, dtype: int64
# ~Кол-во пропущенных значений для столбца year_to_work~: 0
# ~Уникальные значения для столбца target_reg~: 1891
# ~Кол-во дубликатов для столбца target_reg~: 446
# ~Первые 3 val counts для столбца target_reg~:
# 41.52    5
# 32.19    5
# 26.58    4
# Name: target_reg, dtype: int64
# ~Кол-во пропущенных значений для столбца target_reg~: 0
# ~Уникальные значения для столбца target_class~: 9
# ~Кол-во дубликатов для столбца target_class~: 2328
# ~Первые 3 val counts для столбца target_class~:
# engine_overheat    289
# gear_stick         284
# another_bug        279
# Name: target_class, dtype: int64
# ~Кол-во пропущенных значений для столбца target_class~: 0

# %%
check_data_distribution(driver_info)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15153 entries, 0 to 15152
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   age                 15153 non-null  int64
#  1   user_rating         15153 non-null  float64
#  2   user_rides          15153 non-null  int64
#  3   user_time_accident  14182 non-null  float64
#  4   user_id             15153 non-null  object
#  5   sex                 15153 non-null  int64
#  6   first_ride_date     15153 non-null  object
# dtypes: float64(2), int64(3), object(2)
# memory usage: 828.8+ KB
# Размерность: (15153, 7)
# Кол-во признаков с Infinite Values: 0
# Кол-во Nan: 971
# Признаки с большими значениями по модулю: Index([], dtype='object')
# Минимум набора: 0.0
# Максимум набора: 3316.0
# Дубликаты в рядах: False
# Дубликаты в столбцах: False
# Неинформативные признаки: []

# %%
analyze_dataset_columns(driver_info)
# Out:
# ~Уникальные значения для столбца age~: 46
# ~Кол-во дубликатов для столбца age~: 15107
# ~Первые 3 val counts для столбца age~:
# 18    1130
# 40     518
# 36     505
# Name: age, dtype: int64
# ~Кол-во пропущенных значений для столбца age~: 0
# ~Уникальные значения для столбца user_rating~: 43
# ~Кол-во дубликатов для столбца user_rating~: 15110
# ~Первые 3 val counts для столбца user_rating~:
# 8.0    907
# 8.1    906
# 8.2    896
# Name: user_rating, dtype: int64
# ~Кол-во пропущенных значений для столбца user_rating~: 0
# ~Уникальные значения для столбца user_rides~: 1800
# ~Кол-во дубликатов для столбца user_rides~: 13353
# ~Первые 3 val counts для столбца user_rides~:
# 881     51
# 757     46
# 1146    46
# Name: user_rides, dtype: int64
# ~Кол-во пропущенных значений для столбца user_rides~: 0
# ~Уникальные значения для столбца user_time_accident~: 84
# ~Кол-во дубликатов для столбца user_time_accident~: 15068
# ~Первые 3 val counts для столбца user_time_accident~:
# 6.0    843
# 3.0    794
# 8.0    777
# Name: user_time_accident, dtype: int64
# ~Кол-во пропущенных значений для столбца user_time_accident~: 971
# ~Уникальные значения для столбца user_id~: 15153
# ~Кол-во дубликатов для столбца user_id~: 0
# ~Первые 3 val counts для столбца user_id~:
# l17437965W    1
# q14446774Z    1
# A76583526S    1
# Name: user_id, dtype: int64
# ~Кол-во пропущенных значений для столбца user_id~: 0
# ~Уникальные значения для столбца sex~: 2
# ~Кол-во дубликатов для столбца sex~: 15151
# ~Первые 3 val counts для столбца sex~:
# 0    7577
# 1    7576
# Name: sex, dtype: int64
# ~Кол-во пропущенных значений для столбца sex~: 0
# ~Уникальные значения для столбца first_ride_date~: 1653
# ~Кол-во дубликатов для столбца first_ride_date~: 13500
# ~Первые 3 val counts для столбца first_ride_date~:
# 2019-1-30    43
# 2019-2-30    42
# 2019-1-27    39
# Name: first_ride_date, dtype: int64
# ~Кол-во пропущенных значений для столбца first_ride_date~: 0

# %%
check_data_distribution(fix_info)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146000 entries, 0 to 145999
# Data columns (total 6 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   car_id          146000 non-null  object
#  1   worker_id       146000 non-null  object
#  2   fix_date        146000 non-null  object
#  3   work_type       146000 non-null  object
#  4   destroy_degree  146000 non-null  float64
#  5   work_duration   146000 non-null  int64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB
# Размерность: (146000, 6)
# Кол-во признаков с Infinite Values: 0
# Кол-во Nan: 0
# Признаки с большими значениями по модулю: Index([], dtype='object')
# Минимум набора: 1.0
# Максимум набора: 74.0
# Дубликаты в рядах: False
# Дубликаты в столбцах: False
# Неинформативные признаки: []

# %%
analyze_dataset_columns(fix_info)
# Out:
# ~Уникальные значения для столбца car_id~: 4250
# ~Кол-во дубликатов для столбца car_id~: 141750
# ~Первые 3 val counts для столбца car_id~:
# P17494612l    35
# k-1039028Y    35
# l-5953507c    35
# Name: car_id, dtype: int64
# ~Кол-во пропущенных значений для столбца car_id~: 0
# ~Уникальные значения для столбца worker_id~: 546
# ~Кол-во дубликатов для столбца worker_id~: 145454
# ~Первые 3 val counts для столбца worker_id~:
# CH    321
# FZ    306
# EY    306
# Name: worker_id, dtype: int64
# ~Кол-во пропущенных значений для столбца worker_id~: 0
# ~Уникальные значения для столбца fix_date~: 138311
# ~Кол-во дубликатов для столбца fix_date~: 7689
# ~Первые 3 val counts для столбца fix_date~:
# 2019-7-28 11:46    4
# 2020-8-17 5:11     4
# 2019-3-16 6:19     4
# Name: fix_date, dtype: int64
# ~Кол-во пропущенных значений для столбца fix_date~: 0
# ~Уникальные значения для столбца work_type~: 6
# ~Кол-во дубликатов для столбца work_type~: 145994
# ~Первые 3 val counts для столбца work_type~:
# repair          67733
# reparking       60533
# refuel_check    10136
# Name: work_type, dtype: int64
# ~Кол-во пропущенных значений для столбца work_type~: 0
# ~Уникальные значения для столбца destroy_degree~: 83
# ~Кол-во дубликатов для столбца destroy_degree~: 145917
# ~Первые 3 val counts для столбца destroy_degree~:
# 1.0     72057
# 5.0     14749
# 10.0     5732
# Name: destroy_degree, dtype: int64
# ~Кол-во пропущенных значений для столбца destroy_degree~: 0
# ~Уникальные значения для столбца work_duration~: 74
# ~Кол-во дубликатов для столбца work_duration~: 145926
# ~Первые 3 val counts для столбца work_duration~:
# 28    7577
# 26    7533
# 27    7521
# Name: work_duration, dtype: int64
# ~Кол-во пропущенных значений для столбца work_duration~: 0

# %%
get_group_duplicates(fix_info, ['car_id', 'fix_date', 'work_type'])
# Out:
# ~Кол-во дубликатов для столбцов car_id, fix_date, work_type~: 1

# %%
get_group_duplicates(fix_info, ['car_id', 'fix_date', 'work_type', 'worker_id'])
# Out:
# ~Кол-во дубликатов для столбцов car_id, fix_date, work_type, worker_id~: 0

# %%
def aggregate_fix_info(df):
    aggregated_df = df.groupby('car_id').agg(
        repairs_count=('car_id', 'size'),
        avg_destroy_degree=('destroy_degree', 'mean'),
        total_work_duration=('work_duration', 'sum')
    ).reset_index()

    return aggregated_df

# %%
fix_info_agg = aggregate_fix_info(fix_info)

# %%
check_data_distribution(fix_info_agg)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4250 entries, 0 to 4249
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   car_id               4250 non-null   object
#  1   repairs_count        4250 non-null   int64
#  2   avg_destroy_degree   4250 non-null   float64
#  3   total_work_duration  4250 non-null   int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 132.9+ KB
# Размерность: (4250, 4)
# Кол-во признаков с Infinite Values: 0
# Кол-во Nan: 0
# Признаки с большими значениями по модулю: Index([], dtype='object')
# Минимум набора: 1.785294117647059
# Максимум набора: 1203.0
# Дубликаты в рядах: False
# Дубликаты в столбцах: False
# Неинформативные признаки: []

# %%
# объединим rides_driver_info_merged_agg с fix_info_agg
rides_driver_fix_info_merged_agg = pd.merge(rides_driver_info_merged_agg, fix_info_agg, on='car_id', how='inner')

# %%
check_data_distribution(rides_driver_fix_info_merged_agg)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4250 entries, 0 to 4249
# Data columns (total 15 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   car_id                        4250 non-null   object
#  1   min_rating                    4250 non-null   float64
#  2   avg_rating                    4250 non-null   float64
#  3   total_distance                4250 non-null   float64
#  4   max_speed                     4250 non-null   float64
#  5   total_rides                   4250 non-null   int64
#  6   sum_user_rides                4250 non-null   int64
#  7   sum_user_time_accident        4250 non-null   float64
#  8   mean_user_time_accident       4250 non-null   float64
#  9   deviation_normal_mean         4250 non-null   float64
#  10  deviation_normalmin_max_diff  4250 non-null   float64
#  11  count_above_75th              4250 non-null   float64
#  12  repairs_count                 4250 non-null   int64
#  13  avg_destroy_degree            4250 non-null   float64
#  14  total_work_duration           4250 non-null   int64
# dtypes: float64(10), int64(4), object(1)
# memory usage: 531.2+ KB
# Размерность: (4250, 15)
# Кол-во признаков с Infinite Values: 0
# Кол-во Nan: 0
# Признаки с большими значениями по модулю: Index([], dtype='object')
# Минимум набора: -67.43761494252874
# Максимум набора: 32563653.0931651
# Дубликаты в рядах: False
# Дубликаты в столбцах: False
# Неинформативные признаки: ['total_rides']

# %%
check_data_distribution(car_train)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2337 entries, 0 to 2336
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   car_id         2337 non-null   object
#  1   model          2337 non-null   object
#  2   car_type       2337 non-null   object
#  3   fuel_type      2337 non-null   object
#  4   car_rating     2337 non-null   float64
#  5   year_to_start  2337 non-null   int64
#  6   riders         2337 non-null   int64
#  7   year_to_work   2337 non-null   int64
#  8   target_reg     2337 non-null   float64
#  9   target_class   2337 non-null   object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 182.7+ KB
# Размерность: (2337, 10)
# Кол-во признаков с Infinite Values: 0
# Кол-во Nan: 0
# Признаки с большими значениями по модулю: Index([], dtype='object')
# Минимум набора: 0.98
# Максимум набора: 142862.0
# Дубликаты в рядах: False
# Дубликаты в столбцах: False
# Неинформативные признаки: []

# %%
# объединим rides_driver_fix_info_merged_agg с car_train
rides_driver_fix_car_train_merged_left = pd.merge(car_train, rides_driver_fix_info_merged_agg, on='car_id', how='left')

# %%
check_data_distribution(rides_driver_fix_car_train_merged_left)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2337 entries, 0 to 2336
# Data columns (total 24 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   car_id                        2337 non-null   object
#  1   model                         2337 non-null   object
#  2   car_type                      2337 non-null   object
#  3   fuel_type                     2337 non-null   object
#  4   car_rating                    2337 non-null   float64
#  5   year_to_start                 2337 non-null   int64
#  6   riders                        2337 non-null   int64
#  7   year_to_work                  2337 non-null   int64
#  8   target_reg                    2337 non-null   float64
#  9   target_class                  2337 non-null   object
#  10  min_rating                    2337 non-null   float64
#  11  avg_rating                    2337 non-null   float64
#  12  total_distance                2337 non-null   float64
#  13  max_speed                     2337 non-null   float64
#  14  total_rides                   2337 non-null   int64
#  15  sum_user_rides                2337 non-null   int64
#  16  sum_user_time_accident        2337 non-null   float64
#  17  mean_user_time_accident       2337 non-null   float64
#  18  deviation_normal_mean         2337 non-null   float64
#  19  deviation_normalmin_max_diff  2337 non-null   float64
#  20  count_above_75th              2337 non-null   float64
#  21  repairs_count                 2337 non-null   int64
#  22  avg_destroy_degree            2337 non-null   float64
#  23  total_work_duration           2337 non-null   int64
# dtypes: float64(12), int64(7), object(5)
# memory usage: 456.4+ KB
# Размерность: (2337, 24)
# Кол-во признаков с Infinite Values: 0
# Кол-во Nan: 0
# Признаки с большими значениями по модулю: Index([], dtype='object')
# Минимум набора: -67.43761494252874
# Максимум набора: 31197854.66144909
# Дубликаты в рядах: False
# Дубликаты в столбцах: False
# Неинформативные признаки: ['total_rides']

# %% [markdown]
# ## Задание 2. Применение методов фильтрации признаков (4 балла)
#
# <center> <img src="https://ucarecdn.com/d1b4bc78-fd04-44fb-bdbf-0a63355b7384/" width=700>

# %% [markdown]
# 1. Выберите и примените любые 3 (можно и больше) метода фильтрации, которые указаны выше или в ноутбуке по фильтрации из полезных ссылок.
# 2. Проинтерпретируйте результаты и сделайте выводы.
#
#
# <h4> Критерии оценивания </h4>
#
# - Применены методы фильтрации — 1 балл за каждый метод, максимум 3 балла.
# - Сделаны выводы на основе примененных методов —1 балл.
# </div>

# %% [markdown]
# ### Советы по Feature Selection

# %% [markdown]
# <div class="alert alert-info">
#
# <h3><center>Зачем отбирать признаки</center></h3>
#
# **Основные причины**:
#
# - Главная причина: с увеличением количества признаков часто падает точность предсказания модели, а некоторые модели и вовсе перестают адекватно работать. Так происходит, если в данных большое количество мусорных фичей (почти не коррелирующих с таргетом).
#
# - Если фичей очень много, то данные перестают помещаться в память и существенно увеличивают время обучения модели, особенно если мы тестируем несколько алгоритмов или ансамбль. Также важно учитывать, что платформы имеют ограничения на длительность одной сессии (в Kaggle — 12 часов) и лимиты по потребляемой памяти.
#
# - Даже если точность не снижается, есть риск, что модель опирается на шумные фичи, что снизит стабильность прогноза на приватной выборке.

# %% [markdown]
# <b>Что удалить сразу:</b>
#
# - константы;
# - уникальные значения (в том числе в тесте; как правило, это ID-шники по типу `car_id`).
#
# <b>Какие методы использовать:</b>
#
# - `Линейная корреляция`.
# - `Phik` — тоже корреляция, но на стероидах ([туториал на Medium](https://towardsdatascience.com/phik-k-get-familiar-with-the-latest-correlation-coefficient-9ba0032b37e7)).
# - `Permutation importance` (из `scikit-learn`).
# - `SHAP values` (из библиотеки `shap`).
# - `CatBoost Feature Selection` (рекурсивные методы).

# %% [markdown]
# # РЕШЕНИЕ: Задание 2: Фильтрация признаков

# %%
analyze_dataset_columns(rides_driver_fix_car_train_merged_left)
# Out:
# ~Уникальные значения для столбца car_id~: 2337
# ~Кол-во дубликатов для столбца car_id~: 0
# ~Первые 3 val counts для столбца car_id~:
# y13744087j    1
# s48916749r    1
# T77801635B    1
# Name: car_id, dtype: int64
# ~Кол-во пропущенных значений для столбца car_id~: 0
# ~Уникальные значения для столбца model~: 26
# ~Кол-во дубликатов для столбца model~: 2311
# ~Первые 3 val counts для столбца model~:
# Hyundai Solaris    161
# Smart ForFour      158
# Renault Kaptur     154
# Name: model, dtype: int64
# ~Кол-во пропущенных значений для столбца model~: 0
# ~Уникальные значения для столбца car_type~: 4
# ~Кол-во дубликатов для столбца car_type~: 2333
# ~Первые 3 val counts для столбца car_type~:
# economy     1536
# standart     599
# business     117
# Name: car_type, dtype: int64
# ~Кол-во пропущенных значений для столбца car_type~: 0
# ~Уникальные значения для столбца fuel_type~: 2
# ~Кол-во дубликатов для столбца fuel_type~: 2335
# ~Первые 3 val counts для столбца fuel_type~:
# petrol     2289
# electro      48
# Name: fuel_type, dtype: int64
# ~Кол-во пропущенных значений для столбца fuel_type~: 0
# ~Уникальные значения для столбца car_rating~: 269
# ~Кол-во дубликатов для столбца car_rating~: 2068
# ~Первые 3 val counts для столбца car_rating~:
# 4.70    30
# 4.28    29
# 4.48    27
# Name: car_rating, dtype: int64
# ~Кол-во пропущенных значений для столбца car_rating~: 0
# ~Уникальные значения для столбца year_to_start~: 7
# ~Кол-во дубликатов для столбца year_to_start~: 2330
# ~Первые 3 val counts для столбца year_to_start~:
# 2015    604
# 2014    451
# 2013    433
# Name: year_to_start, dtype: int64
# ~Кол-во пропущенных значений для столбца year_to_start~: 0
# ~Уникальные значения для столбца riders~: 2306
# ~Кол-во дубликатов для столбца riders~: 31
# ~Первые 3 val counts для столбца riders~:
# 44425    2
# 86195    2
# 20727    2
# Name: riders, dtype: int64
# ~Кол-во пропущенных значений для столбца riders~: 0
# ~Уникальные значения для столбца year_to_work~: 9
# ~Кол-во дубликатов для столбца year_to_work~: 2328
# ~Первые 3 val counts для столбца year_to_work~:
# 2019    346
# 2018    337
# 2020    336
# Name: year_to_work, dtype: int64
# ~Кол-во пропущенных значений для столбца year_to_work~: 0
# ~Уникальные значения для столбца target_reg~: 1891
# ~Кол-во дубликатов для столбца target_reg~: 446
# ~Первые 3 val counts для столбца target_reg~:
# 41.52    5
# 32.19    5
# 26.58    4
# Name: target_reg, dtype: int64
# ~Кол-во пропущенных значений для столбца target_reg~: 0
# ~Уникальные значения для столбца target_class~: 9
# ~Кол-во дубликатов для столбца target_class~: 2328
# ~Первые 3 val counts для столбца target_class~:
# engine_overheat    289
# gear_stick         284
# another_bug        279
# Name: target_class, dtype: int64
# ~Кол-во пропущенных значений для столбца target_class~: 0
# ~Уникальные значения для столбца min_rating~: 91
# ~Кол-во дубликатов для столбца min_rating~: 2246
# ~Первые 3 val counts для столбца min_rating~:
# 0.10    1756
# 0.00     249
# 0.19      12
# Name: min_rating, dtype: int64
# ~Кол-во пропущенных значений для столбца min_rating~: 0
# ~Уникальные значения для столбца avg_rating~: 2223
# ~Кол-во дубликатов для столбца avg_rating~: 114
# ~Первые 3 val counts для столбца avg_rating~:
# 4.559195    3
# 4.557874    3
# 4.170345    3
# Name: avg_rating, dtype: int64
# ~Кол-во пропущенных значений для столбца avg_rating~: 0
# ~Уникальные значения для столбца total_distance~: 2337
# ~Кол-во дубликатов для столбца total_distance~: 0
# ~Первые 3 val counts для столбца total_distance~:
# 1.214131e+07    1
# 1.625204e+07    1
# 8.311905e+06    1
# Name: total_distance, dtype: int64
# ~Кол-во пропущенных значений для столбца total_distance~: 0
# ~Уникальные значения для столбца max_speed~: 1938
# ~Кол-во дубликатов для столбца max_speed~: 399
# ~Первые 3 val counts для столбца max_speed~:
# 200.0    114
# 119.0     22
# 187.0     14
# Name: max_speed, dtype: int64
# ~Кол-во пропущенных значений для столбца max_speed~: 0
# ~Уникальные значения для столбца total_rides~: 1
# ~Кол-во дубликатов для столбца total_rides~: 2336
# ~Первые 3 val counts для столбца total_rides~:
# 174    2337
# Name: total_rides, dtype: int64
# ~Кол-во пропущенных значений для столбца total_rides~: 0
# ~Уникальные значения для столбца sum_user_rides~: 2255
# ~Кол-во дубликатов для столбца sum_user_rides~: 82
# ~Первые 3 val counts для столбца sum_user_rides~:
# 152545    3
# 142736    3
# 152381    2
# Name: sum_user_rides, dtype: int64
# ~Кол-во пропущенных значений для столбца sum_user_rides~: 0
# ~Уникальные значения для столбца sum_user_time_accident~: 1007
# ~Кол-во дубликатов для столбца sum_user_time_accident~: 1330
# ~Первые 3 val counts для столбца sum_user_time_accident~:
# 1296.0    10
# 1281.0     9
# 1587.0     9
# Name: sum_user_time_accident, dtype: int64
# ~Кол-во пропущенных значений для столбца sum_user_time_accident~: 0
# ~Уникальные значения для столбца mean_user_time_accident~: 1654
# ~Кол-во дубликатов для столбца mean_user_time_accident~: 683
# ~Первые 3 val counts для столбца mean_user_time_accident~:
# 7.448276    9
# 7.402299    8
# 7.528736    7
# Name: mean_user_time_accident, dtype: int64
# ~Кол-во пропущенных значений для столбца mean_user_time_accident~: 0
# ~Уникальные значения для столбца deviation_normal_mean~: 2334
# ~Кол-во дубликатов для столбца deviation_normal_mean~: 3
# ~Первые 3 val counts для столбца deviation_normal_mean~:
# -4.179879    2
# -2.199356    2
# -2.565833    2
# Name: deviation_normal_mean, dtype: int64
# ~Кол-во пропущенных значений для столбца deviation_normal_mean~: 0
# ~Уникальные значения для столбца deviation_normalmin_max_diff~: 2072
# ~Кол-во дубликатов для столбца deviation_normalmin_max_diff~: 265
# ~Первые 3 val counts для столбца deviation_normalmin_max_diff~:
# 10.001    13
# 10.000     9
# 29.017     8
# Name: deviation_normalmin_max_diff, dtype: int64
# ~Кол-во пропущенных значений для столбца deviation_normalmin_max_diff~: 0
# ~Уникальные значения для столбца count_above_75th~: 173
# ~Кол-во дубликатов для столбца count_above_75th~: 2164
# ~Первые 3 val counts для столбца count_above_75th~:
# 0.0    844
# 1.0     45
# 3.0     29
# Name: count_above_75th, dtype: int64
# ~Кол-во пропущенных значений для столбца count_above_75th~: 0
# ~Уникальные значения для столбца repairs_count~: 2
# ~Кол-во дубликатов для столбца repairs_count~: 2335
# ~Первые 3 val counts для столбца repairs_count~:
# 34    1505
# 35     832
# Name: repairs_count, dtype: int64
# ~Кол-во пропущенных значений для столбца repairs_count~: 0
# ~Уникальные значения для столбца avg_destroy_degree~: 1163
# ~Кол-во дубликатов для столбца avg_destroy_degree~: 1174
# ~Первые 3 val counts для столбца avg_destroy_degree~:
# 3.385294    8
# 2.832353    7
# 3.494118    7
# Name: avg_destroy_degree, dtype: int64
# ~Кол-во пропущенных значений для столбца avg_destroy_degree~: 0
# ~Уникальные значения для столбца total_work_duration~: 372
# ~Кол-во дубликатов для столбца total_work_duration~: 1965
# ~Первые 3 val counts для столбца total_work_duration~:
# 921    20
# 906    20
# 905    20
# Name: total_work_duration, dtype: int64
# ~Кол-во пропущенных значений для столбца total_work_duration~: 0

# %%
import numpy as np
import pandas as pd

bug_dict = {
    'break_bug':   		0,
    'wheel_shake': 		1,
    'engine_check':		2,
    'engine_fuel': 		3,
    'electro_bug': 		4,
    'gear_stick':  		5,
    'engine_ignition':  6,
    'engine_overheat':  7,
    'another_bug': 		8
    }
def encode_repair_types(df, bug_dict, repair_type_col='target_class'):
    df[repair_type_col] = df[repair_type_col].map(bug_dict)

    return df

def add_uniform_random_feature(df, feature_name='random_feature', low=0.0, high=1.0):
    df[feature_name] = np.random.uniform(low, high, size=df.shape[0])
    return df

# %%
labeled_target_fitration_df = encode_repair_types(rides_driver_fix_car_train_merged_left, bug_dict, 'target_class')

# %%
labeled_target_fitration_df['target_class'].unique()
# Out:
# array([8, 4, 5, 3, 6, 7, 2, 1, 0])

# %%
labeled_target_fitration_df = add_uniform_random_feature(labeled_target_fitration_df)

# %%
labeled_target_fitration_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2337 entries, 0 to 2336
# Data columns (total 25 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   car_id                        2337 non-null   int64
#  1   model                         2337 non-null   int64
#  2   car_type                      2337 non-null   int64
#  3   fuel_type                     2337 non-null   int64
#  4   car_rating                    2337 non-null   float64
#  5   year_to_start                 2337 non-null   int64
#  6   riders                        2337 non-null   int64
#  7   year_to_work                  2337 non-null   int64
#  8   target_reg                    2337 non-null   float64
#  9   target_class                  2337 non-null   int64
#  10  min_rating                    2337 non-null   float64
#  11  avg_rating                    2337 non-null   float64
#  12  total_distance                2337 non-null   float64
#  13  max_speed                     2337 non-null   float64
#  14  total_rides                   2337 non-null   int64
#  15  sum_user_rides                2337 non-null   int64
#  16  sum_user_time_accident        2337 non-null   float64
#  17  mean_user_time_accident       2337 non-null   float64
#  18  deviation_normal_mean         2337 non-null   float64
#  19  deviation_normalmin_max_diff  2337 non-null   float64
#  20  count_above_75th              2337 non-null   float64
#  21  repairs_count                 2337 non-null   int64
#  22  avg_destroy_degree            2337 non-null   float64
#  23  total_work_duration           2337 non-null   int64
#  24  random_feature                2337 non-null   float64
# dtypes: float64(13), int64(12)
# memory usage: 474.7 KB

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

def show_correlation_analysis(df, target_col_name, features_limit):
    corrs = df.dropna().corr().round(3)

    sorted_corrs = corrs[target_col_name].abs().sort_values(ascending=False)

    top_features = sorted_corrs[:features_limit + 1].index.tolist()

    filtered_corrs = corrs.loc[top_features, top_features]

    plt.figure(figsize=(10, 8))
    sns.heatmap(filtered_corrs,
                cmap='Greens',
                square=True,
                annot=True,
                vmin=0)
    plt.title(f'Top из {features_limit} корреляции признаков с {target_col_name}')
    plt.show()

# %%
show_correlation_analysis(labeled_target_fitration_df, 'target_reg', 100)

# %%
show_correlation_analysis(labeled_target_fitration_df, 'target_class', 100)

# %%
# !pip install phik
import phik
from phik import report
from phik.report import plot_correlation_matrix
import matplotlib.pyplot as plt

def show_correlation_by_phik(df, target_col_name, features_limit):
    if target_col_name not in df.columns:
        raise ValueError(f"{target_col_name} отсутствует в наборе")

    phik_overview = df.phik_matrix().round(2)

    sorted_cols = phik_overview[target_col_name].abs().sort_values(ascending=False).index

    top_features = sorted_cols[:features_limit + 1]

    filtered_phik_overview = phik_overview.loc[top_features, top_features]

    plot_correlation_matrix(filtered_phik_overview.values,
                            x_labels=filtered_phik_overview.columns,
                            y_labels=filtered_phik_overview.index,
                            vmin=0, vmax=1, color_map="Greens",
                            title=r"Phik корреляция $\phi_K$",
                            fontsize_factor=1.2, figsize=(10, 7))
    plt.tight_layout()
    plt.show()
# Out:
# Requirement already satisfied: phik in /usr/local/lib/python3.10/dist-packages (0.12.4)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from phik) (1.25.2)
# Requirement already satisfied: scipy>=1.5.2 in /usr/local/lib/python3.10/dist-packages (from phik) (1.11.4)
# Requirement already satisfied: pandas>=0.25.1 in /usr/local/lib/python3.10/dist-packages (from phik) (1.5.3)
# Requirement already satisfied: matplotlib>=2.2.3 in /usr/local/lib/python3.10/dist-packages (from phik) (3.7.1)
# Requirement already satisfied: joblib>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from phik) (1.3.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.3->phik) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.3->phik) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.3->phik) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.3->phik) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.3->phik) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.3->phik) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.3->phik) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.3->phik) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25.1->phik) (2023.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=2.2.3->phik) (1.16.0)

# %%
show_correlation_by_phik(labeled_target_fitration_df, 'target_reg', 100)
# Out:
# interval columns not set, guessing: ['car_id', 'model', 'car_type', 'fuel_type', 'car_rating', 'year_to_start', 'riders', 'year_to_work', 'target_reg', 'target_class', 'min_rating', 'avg_rating', 'total_distance', 'max_speed', 'total_rides', 'sum_user_rides', 'sum_user_time_accident', 'mean_user_time_accident', 'deviation_normal_mean', 'deviation_normalmin_max_diff', 'count_above_75th', 'repairs_count', 'avg_destroy_degree', 'total_work_duration', 'random_feature']
# /usr/local/lib/python3.10/dist-packages/phik/data_quality.py:72: UserWarning: Not enough unique value for variable total_rides for analysis 1. Dropping this column
#   warnings.warn(

# %%
show_correlation_by_phik(labeled_target_fitration_df, 'target_class', 100)
# Out:
# interval columns not set, guessing: ['car_id', 'model', 'car_type', 'fuel_type', 'car_rating', 'year_to_start', 'riders', 'year_to_work', 'target_reg', 'target_class', 'min_rating', 'avg_rating', 'total_distance', 'max_speed', 'total_rides', 'sum_user_rides', 'sum_user_time_accident', 'mean_user_time_accident', 'deviation_normal_mean', 'deviation_normalmin_max_diff', 'count_above_75th', 'repairs_count', 'avg_destroy_degree', 'total_work_duration', 'random_feature']
# /usr/local/lib/python3.10/dist-packages/phik/data_quality.py:72: UserWarning: Not enough unique value for variable total_rides for analysis 1. Dropping this column
#   warnings.warn(

# %%
# !pip install shap
# !pip install xgboost
import xgboost as xgb
from sklearn.model_selection import train_test_split
import xgboost as xgb
import shap

from sklearn.preprocessing import LabelEncoder
import pandas as pd

def encode_categorical_features(df):
    encoders = {}
    df_encoded = df.copy()

    for column in df.columns:
        if df[column].dtype == 'object':
            le = LabelEncoder()
            df_encoded[column] = le.fit_transform(df[column])
            encoders[column] = le

    return df_encoded, encoders

def train_xgb_model(df, target_column, task_type='classification', model_params=None, test_size=0.2, random_state=42, n_estimators=100):
    X = df.drop(columns=[target_column])
    y = df[target_column]
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)
    dtrain = xgb.DMatrix(X_train, label=y_train)
    dtest = xgb.DMatrix(X_test, label=y_test)
    if model_params is None:
        default_objective = 'multi:softprob' if task_type == 'classification' else 'reg:squarederror'
        default_eval_metric = 'mlogloss' if task_type == 'classification' else 'rmse'
        model_params = {
            'max_depth': 3, 'eta': 0.1,
            'objective': default_objective,
            'eval_metric': default_eval_metric
        }
        if task_type == 'classification':
            model_params['num_class'] = len(y.unique())
    bst = xgb.train(model_params, dtrain, n_estimators, evals=[(dtest, 'test')], early_stopping_rounds=10)
    return bst

def generate_shap_summary_xgb(model, df, target_column, features_limit=25):
    X = df.drop(columns=[target_column])
    explainer = shap.TreeExplainer(model)
    shap_values = explainer.shap_values(X)

    if shap_values is None:
        raise ValueError()

    shap.summary_plot(shap_values, X, max_display=features_limit)
    return shap_values

def get_shap_results(df_encoded, target_column, task_type='classification', model_params=None, test_size=0.2, random_state=42, n_estimators=100, features_limit=25):
    bst_model = train_xgb_model(df_encoded, target_column, task_type, model_params, test_size, random_state, n_estimators)
    shap_values = generate_shap_summary_xgb(bst_model, df_encoded, target_column, features_limit)

    # if task_type == 'classification' and isinstance(shap_values, list):
    #     # Calculate mean absolute SHAP values per feature across all classes
    #     mean_abs_shap_values = np.mean([np.abs(values).mean(axis=0) for values in shap_values], axis=0)
    # else:
    #     # For regression or binary classification where shap_values is not a list
    #     mean_abs_shap_values = np.abs(shap_values).mean(axis=0)

    # # Convert the mean absolute SHAP values to a pandas Series for easy manipulation and visualization
    # mean_abs_shap_series = pd.Series(mean_abs_shap_values, index=df_encoded.drop(columns=[target_column]).columns).sort_values(ascending=False)

    return bst_model#, mean_abs_shap_series

# %%
labeled_target_fitration_df, encoders = encode_categorical_features(labeled_target_fitration_df)

# %%
labeled_target_fitration_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2337 entries, 0 to 2336
# Data columns (total 25 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   car_id                        2337 non-null   int64
#  1   model                         2337 non-null   int64
#  2   car_type                      2337 non-null   int64
#  3   fuel_type                     2337 non-null   int64
#  4   car_rating                    2337 non-null   float64
#  5   year_to_start                 2337 non-null   int64
#  6   riders                        2337 non-null   int64
#  7   year_to_work                  2337 non-null   int64
#  8   target_reg                    2337 non-null   float64
#  9   target_class                  2337 non-null   int64
#  10  min_rating                    2337 non-null   float64
#  11  avg_rating                    2337 non-null   float64
#  12  total_distance                2337 non-null   float64
#  13  max_speed                     2337 non-null   float64
#  14  total_rides                   2337 non-null   int64
#  15  sum_user_rides                2337 non-null   int64
#  16  sum_user_time_accident        2337 non-null   float64
#  17  mean_user_time_accident       2337 non-null   float64
#  18  deviation_normal_mean         2337 non-null   float64
#  19  deviation_normalmin_max_diff  2337 non-null   float64
#  20  count_above_75th              2337 non-null   float64
#  21  repairs_count                 2337 non-null   int64
#  22  avg_destroy_degree            2337 non-null   float64
#  23  total_work_duration           2337 non-null   int64
#  24  random_feature                2337 non-null   float64
# dtypes: float64(13), int64(12)
# memory usage: 474.7 KB

# %%
shap_results = get_shap_results(labeled_target_fitration_df, 'target_class')
# Out:
# [0]	test-mlogloss:1.84397
# [1]	test-mlogloss:1.59478
# [2]	test-mlogloss:1.41010
# [3]	test-mlogloss:1.25901
# [4]	test-mlogloss:1.13324
# [5]	test-mlogloss:1.02673
# [6]	test-mlogloss:0.93563
# [7]	test-mlogloss:0.85506
# [8]	test-mlogloss:0.78332
# [9]	test-mlogloss:0.72269
# [10]	test-mlogloss:0.66565
# [11]	test-mlogloss:0.61440
# [12]	test-mlogloss:0.57058
# [13]	test-mlogloss:0.52880
# [14]	test-mlogloss:0.49263
# [15]	test-mlogloss:0.45822
# [16]	test-mlogloss:0.42816
# [17]	test-mlogloss:0.40024
# [18]	test-mlogloss:0.37456
# [19]	test-mlogloss:0.35054
# [20]	test-mlogloss:0.32878
# [21]	test-mlogloss:0.30923
# [22]	test-mlogloss:0.29298
# [23]	test-mlogloss:0.27590
# [24]	test-mlogloss:0.26102
# [25]	test-mlogloss:0.24679
# [26]	test-mlogloss:0.23376
# [27]	test-mlogloss:0.22147
# [28]	test-mlogloss:0.21012
# [29]	test-mlogloss:0.19962
# [30]	test-mlogloss:0.18962
# [31]	test-mlogloss:0.18151
# [32]	test-mlogloss:0.17355
# [33]	test-mlogloss:0.16618
# [34]	test-mlogloss:0.15981
# [35]	test-mlogloss:0.15415
# [36]	test-mlogloss:0.14814
# [37]	test-mlogloss:0.14313
# [38]	test-mlogloss:0.13854
# [39]	test-mlogloss:0.13452
# [40]	test-mlogloss:0.13069
# [41]	test-mlogloss:0.12668
# [42]	test-mlogloss:0.12334
# [43]	test-mlogloss:0.11986
# [44]	test-mlogloss:0.11705
# [45]	test-mlogloss:0.11431
# [46]	test-mlogloss:0.11112
# [47]	test-mlogloss:0.10892
# [48]	test-mlogloss:0.10699
# [49]	test-mlogloss:0.10509
# [50]	test-mlogloss:0.10357
# [51]	test-mlogloss:0.10182
# [52]	test-mlogloss:0.10021
# [53]	test-mlogloss:0.09879
# [54]	test-mlogloss:0.09734
# [55]	test-mlogloss:0.09645
# [56]	test-mlogloss:0.09503
# [57]	test-mlogloss:0.09380
# [58]	test-mlogloss:0.09292
# [59]	test-mlogloss:0.09206
# [60]	test-mlogloss:0.09138
# [61]	test-mlogloss:0.09050
# [62]	test-mlogloss:0.08959
# [63]	test-mlogloss:0.08902
# [64]	test-mlogloss:0.08806
# [65]	test-mlogloss:0.08762
# [66]	test-mlogloss:0.08697
# [67]	test-mlogloss:0.08634
# [68]	test-mlogloss:0.08552
# [69]	test-mlogloss:0.08488
# [70]	test-mlogloss:0.08456
# [71]	test-mlogloss:0.08401
# [72]	test-mlogloss:0.08332
# [73]	test-mlogloss:0.08299
# [74]	test-mlogloss:0.08297
# [75]	test-mlogloss:0.08298
# [76]	test-mlogloss:0.08283
# [77]	test-mlogloss:0.08226
# [78]	test-mlogloss:0.08185
# [79]	test-mlogloss:0.08171
# [80]	test-mlogloss:0.08159
# [81]	test-mlogloss:0.08155
# [82]	test-mlogloss:0.08129
# [83]	test-mlogloss:0.08092
# [84]	test-mlogloss:0.08091
# [85]	test-mlogloss:0.08058
# [86]	test-mlogloss:0.08043
# [87]	test-mlogloss:0.08019
# [88]	test-mlogloss:0.07992
# [89]	test-mlogloss:0.07943
# [90]	test-mlogloss:0.07955
# [91]	test-mlogloss:0.07951
# [92]	test-mlogloss:0.07954
# [93]	test-mlogloss:0.07968
# [94]	test-mlogloss:0.07966
# [95]	test-mlogloss:0.07943
# [96]	test-mlogloss:0.07937
# [97]	test-mlogloss:0.07946
# [98]	test-mlogloss:0.07994
# [99]	test-mlogloss:0.07967

# %%
shap_results = get_shap_results(labeled_target_fitration_df, 'target_reg', 'regr')
# Out:
# [0]	test-rmse:17.06604
# [1]	test-rmse:16.03083
# [2]	test-rmse:15.15292
# [3]	test-rmse:14.37245
# [4]	test-rmse:13.67882
# [5]	test-rmse:13.01981
# [6]	test-rmse:12.48980
# [7]	test-rmse:11.98736
# [8]	test-rmse:11.47488
# [9]	test-rmse:10.98870
# [10]	test-rmse:10.59042
# [11]	test-rmse:10.22713
# [12]	test-rmse:9.97172
# [13]	test-rmse:9.72151
# [14]	test-rmse:9.49320
# [15]	test-rmse:9.32512
# [16]	test-rmse:9.15957
# [17]	test-rmse:9.00029
# [18]	test-rmse:8.84564
# [19]	test-rmse:8.74015
# [20]	test-rmse:8.65955
# [21]	test-rmse:8.57671
# [22]	test-rmse:8.45514
# [23]	test-rmse:8.38008
# [24]	test-rmse:8.27706
# [25]	test-rmse:8.18328
# [26]	test-rmse:8.12911
# [27]	test-rmse:8.08223
# [28]	test-rmse:8.04633
# [29]	test-rmse:7.99839
# [30]	test-rmse:7.95238
# [31]	test-rmse:7.89026
# [32]	test-rmse:7.85677
# [33]	test-rmse:7.84791
# [34]	test-rmse:7.80705
# [35]	test-rmse:7.77358
# [36]	test-rmse:7.74914
# [37]	test-rmse:7.74984
# [38]	test-rmse:7.72396
# [39]	test-rmse:7.72041
# [40]	test-rmse:7.68951
# [41]	test-rmse:7.65162
# [42]	test-rmse:7.64148
# [43]	test-rmse:7.62942
# [44]	test-rmse:7.61471
# [45]	test-rmse:7.60839
# [46]	test-rmse:7.61383
# [47]	test-rmse:7.58650
# [48]	test-rmse:7.56024
# [49]	test-rmse:7.55509
# [50]	test-rmse:7.54836
# [51]	test-rmse:7.53768
# [52]	test-rmse:7.51426
# [53]	test-rmse:7.49975
# [54]	test-rmse:7.50276
# [55]	test-rmse:7.48099
# [56]	test-rmse:7.47736
# [57]	test-rmse:7.47371
# [58]	test-rmse:7.46981
# [59]	test-rmse:7.46807
# [60]	test-rmse:7.46447
# [61]	test-rmse:7.45688
# [62]	test-rmse:7.46739
# [63]	test-rmse:7.45305
# [64]	test-rmse:7.45203
# [65]	test-rmse:7.43213
# [66]	test-rmse:7.43144
# [67]	test-rmse:7.41116
# [68]	test-rmse:7.40465
# [69]	test-rmse:7.40618
# [70]	test-rmse:7.40403
# [71]	test-rmse:7.39950
# [72]	test-rmse:7.40389
# [73]	test-rmse:7.40067
# [74]	test-rmse:7.38403
# [75]	test-rmse:7.38036
# [76]	test-rmse:7.38102
# [77]	test-rmse:7.38104
# [78]	test-rmse:7.37749
# [79]	test-rmse:7.38161
# [80]	test-rmse:7.37123
# [81]	test-rmse:7.37066
# [82]	test-rmse:7.36041
# [83]	test-rmse:7.35451
# [84]	test-rmse:7.35636
# [85]	test-rmse:7.35692
# [86]	test-rmse:7.35168
# [87]	test-rmse:7.35575
# [88]	test-rmse:7.34682
# [89]	test-rmse:7.34511
# [90]	test-rmse:7.34665
# [91]	test-rmse:7.34708
# [92]	test-rmse:7.34101
# [93]	test-rmse:7.33628
# [94]	test-rmse:7.34105
# [95]	test-rmse:7.33636
# [96]	test-rmse:7.33781
# [97]	test-rmse:7.34015
# [98]	test-rmse:7.33774
# [99]	test-rmse:7.32699

# %% [markdown]
# Как видно, для признака target_reg требуется удалить riders
# для признака target_class - удалить cars_rating

# %% [markdown]
# # Домашнее задание 2. Прогноз времени и вида поломки машин. Настройка ML-модели

# %% [markdown]
# <div class="alert alert-info">
#
# **Цель блока** — составить тренировочную и валидационную выборки, произвести обучение модели `CatBoostClassifier` на тренировочной части и оценить качество на валидационной.

# %% [markdown]
# ##Обучение первой модели (5 баллов)
#
# 1.   Новый пункт
# 2.   Новый пункт

# %% [markdown]
# 1. Классифицируйте признаки на типы (категориальные, числовые, таргеты).
#
# 2. Выделите в `X` только признаки, а в `Y` — таргет (для задачи классификации).
#
# 3. Сделайте разделение данных на *обучающую* и *валидационную* выборки (не забывайте про воспроизводимость результатов).
#
# 4. Создайте и обучите `CatBoostClassifier` модель (настраивать гиперпараметры сейчас не обязательно).
#
# 5. Проведите оценку вашей модели, используя метрику `accuracy`.
#
#
# <h4> Критерии оценивания </h4>
#
# - По 1 баллу за каждый корректно выполненный пункт.
#
# </div>

# %%
from catboost import CatBoostClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
features2drop = [...] # то, что надо выбросить
targets = [...] # таргеты
cat_features = [...] # категориальные признаки

num_features = [...] # числовые признаки

print('Категориальные признаки:', len(cat_features), cat_features)
print('Числовые признаки:', len(num_features), num_features)
print('Целевые переменные', targets)

# %%
# YOUR CODE HERE

# %% [markdown]
# # Дополнительное задание. Визуализация прогнозов, ошибок модели и важности признаков

# %% [markdown]
# <div class="alert alert-info">
#
# **Цель блока** — визуализировать результаты прогнозирования, ошибки модели и важность признаков для лучшего понимания и анализа модели.

# %% [markdown]
# ## Визуализация (5 баллов)

# %% [markdown]
#
# 1. Визуализируйте важность признаков встроенным методом в `CatBoost`  (помните, что не стоит сильно доверять этому рейтингу важности, т. к. для сильно скоррелированных признаков важность делится пополам — оба признака могут улететь вниз).
#
# 2. Постройте `waterfall_plot` из библиотеки `SHAP` (подробнее во втором ноутбуке из полезных ссылок ниже).
#
# 3. Постройте `classification_report` из библиотеки `scikit-learn`.
#
# 4. Постройте и визуализируйте матрицу смежности (`confusion_matrix`), посмотрите, в каких классах модель больше всего ошибается.
#
# 5. Для каждого графика/примененного метода проинтерпретируйте результаты и сделайте выводы.
#
#
# <h4> Критерии оценивания </h4>
#
# - По 1 баллу за каждый корректно выполненный пункт.
#
# </div>
#
# <div class="alert alert-success">
#
# Визуализация может помочь даже после того, как мы **уже обучили** какую-нибудь модель. Например:
#
# - Понять, что мешает модели или чего не хватает, чтобы не допускать ошибки.
# - Сделать выводы, как можно улучшить точность в последующих экспериментах.
# - Визуализировать ошибки модели.
# - Отсеять лишние признаки.
# - Найти идеи для новых признаков.
# - Все зависит от типа ваших данных.
#
# <h3> Полезные источники </h3>
#
# - Занятие про визуализацию и Seaborn.
# - Занятие про продвинутую визуализацию и анализ ошибок модели.
#
# </div>

# %%
# YOUR CODE HERE

# %% [markdown]
# # Домашнее задание 3. Оптимизация. Тюнинг гиперпараметров с помощью `Optuna`

# %% [markdown]
# <div class="alert alert-info">
#
# **Цель блока** — улучшить качество предсказания, произведя подбор гиперпараметров для модели с помощью `Optuna`.

# %% [markdown]
# ## Подбор гиперпараметров (3 балла)

# %% [markdown]
# 1. Напишите `objective` функцию и запустите `Optuna`.
# 2. Подберите гиперпараметры для `CatBoostClassifier` (минимум 3).
# 3. Обучите модель с новыми гиперпараметрами, сравните качество и сделайте выводы.
#
#
# <h4> Критерии оценивания </h4>
#
# - 1 балл за каждый корректно выполненный пункт.
#
# </div>

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Общая информация по `Optuna`

# %% [markdown]
# #### Ключевые особенности <code>Optuna</code>

# %% [markdown]
# - Легковесность и универсальность — можно подбирать оптимальные параметры под любые функции и метрики.
# - SOTA-алгоритмы, адаптированные для поиска гиперпараметров.
# - Параллелизация и различные методы прунинга.
# - Встроенная визуализация.
# - Интеграция со множеством популярных библиотек (бустинги, sklearn, PyTorch, W&B и другие).
#
# Разберем Optuna по частям, чтобы понять, как ее использовать.

# %% [markdown]
# #### <code>Study</code>: оптимизация, базирующаяся на <code>Objective</code> функции

# %% [markdown]
# В `Objective`-функцию нужно написать код подсчета метрики, которую возвращаем. `Objective` вызывается Optuna много раз для подбора лучших параметров.
# ```python
# def objective(trial, ...):
#     # calculate score...
#     return score
# ```
#
# <h4> <code>Trial</code> — одно выполнение <code>Objective</code>-функции</h4>
#
# В `trial`-объекте мы передаем параметры для «перебора», используя для каждого типа свой метод. Например:
#
# ```python
# # метод `suggest_float` показывает, что перебираем `float` значения, от 0 и до 1.5 границы
# param = trial.suggest_float('param', 0, 1.5)
#
# # Категориальное значение
# loss_function = trial.suggest_categorical('loss', ['Logloss', 'CrossEntropy'])
#
# # Целочисленное значение
# depth = trial.suggest_int('depth', 5, 8)
#
# # Равномерное распределение
# learning_rate = trial.suggest_uniform('learning_rate', 0.0, 1.0)
# ```

# %% [markdown]
# #### `Study` parameters

# %% [markdown]
# Инициализируем объект `study`, который начнет перебор и сохранит в себе историю результатов.
# Если мы стараемся увеличить метрику, а не уменьшить ошибку, то используем `create_study(direction='maximize')`.
# ```python
# study = optuna.create_study()
# study.optimize(objective, n_trials=10)
# ```

# %% [markdown]
# <div class="alert alert-info">
#
# В [`Optuna`](https://optuna.readthedocs.io/en/stable/index.html) реализовано несколько методов (`sampler`) подбора параметров (в том числе классические):
# * `GridSampler`
# * `RandomSampler`
# * `Tree-Structed Parzen Estimator` (`TPESampler` — самый популярный, дефолтный)
# * `BruteForceSampler`
# * [Другие 4 метода](https://optuna.readthedocs.io/en/stable/reference/samplers/index.html#module-optuna.samplers) (можно написать собственный семплер)

# %% [markdown]
# ### Советы по перебору параметров

# %% [markdown]
# - Иметь понимание важности параметров.
# - Число `iterations` лучше взять с запасом и зафиксировать, при этом ограничив через `early_stopping_rounds`.
# - Подсмотреть или чувствовать диапазоны и шаг значений.
# - Исключить то, что перебирать не нужно (`random_seed` , `eval_metric`, `thread_count` и прочее).
# - Используйте информацию с прошлых попыток.

# %% [markdown]
# # Домашнее задание 4. Блендинг

# %% [markdown]
# <div class="alert alert-info">
#
# **Цель блока** — улучшить качество предсказания, объединив несколько моделей вместе методом блендинга.

# %% [markdown]
# ## Задание 6. Блендинг (10 баллов)

# %% [markdown]
# 1. Построить и обучить модели:
#     - `CatBoostClassifier`,
#     - `LightGBMClassifier (goss)`,
#     - `XGBoostClassifier (dart)`,
#     - `RandomForestClassifier`.
# 2. Сделать предсказания каждой моделью, оценить качество.
# 3. Реализовать блендинг двумя способами, оценить качество и сравнить с предыдущим пунктом:
#     - `Hard Voting` —  метод, при котором делаем голосование всех моделей и выбираем самый популярный класс.
#     - `Soft Voting` —  метод, при котором мы складываем вероятности предсказания всех моделей по каждому классу и потом выбираем самый класс с максимальной суммой.
#
# <h4> Критерии оценивания </h4>
#
# - Обучены 4 модели — 1 балл за каждую обученную модель, всего 4 балла.
# - Для модели проведен подбор гиперпараметров — 0,5 балла за каждый параметр, всего 2 балла.
# - Сделаны предсказания каждой модели и оценено качество — 1 балл.
# - Реализован `Hard Voting` — 1 балл.
# - Реализован `Soft Voting` — 1 балл.
# - Сделаны выводы — 1 балл.
#
# </div>

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Общая информация о блендинге

# %% [markdown]
# **Основная идея** — взять от каждого алгоритма лучшее и совместить несколько разных ML-моделей в одну.
#
# Что это дает:
# - Увеличивается обобщающая способность финальной модели и качество улучшается.
# - Модель становится более стабильной, что позволяет не слететь на приватном лидерборде.
#
# Особенно хорошо накидывает блендинг, если смешиваемые модели имеют разную природу — например, нейронные сети, kNN и решающие деревья. Они выучивают разные зависимости и хорошо дополняют друг друга.
#
# </div>

# %% [markdown]
# # <center id="part6"> Отправка финального решения на лидерборд на Kaggle

# %% [markdown]
# <div class="alert alert-info">
#
# **Цель блока** — сделать предсказание с помощью блендинга для тестовой части датасета, отправить результат [в соревнование на Kaggle](https://www.kaggle.com/competitions/competative-data-science-course-by-data-feeling/overview).

# %% [markdown]
# ## Задание 8. Предсказание на тестовом датасете и отправка на Kaggle

# %% [markdown]
# 1. Сделать предобработку для тестового датасета, присоединить к нему информацию из других датасетов и добавить признаки, которые генерировали для тренировочного датасета.
# 2. Сделать предсказания каждой моделью, которую хотите включить в ансамбль, но минимум их должно быть 3.
# 3. Сделать блендинг с помощью `Hard Voting` или `Soft Voting` на ваш выбор.
# 4. Сохранить результат предсказания в `csv` файл и отправить решение на Kaggle.
#
# <h4> Критерии оценивания </h4>
#
# - 0 баллов за задание, если итоговый скор на лидерборде меньше чем `0.9`.
# - 1 балл за каждый выполненный пункт.
#
# </div>

# %%
car_test = pd.read_csv('https://raw.githubusercontent.com/a-milenkin/Competitive_Data_Science/main/data/car_test.csv')
car_test.head(3)

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Советы по отправке кода на Kaggle

# %% [markdown]
# Если пишете код на `Kaggle`, то для отправки решения:
#
# 1. Нажать Save Version.
# 2. Проверить, что в Advanced Settings выбрано «Всегда сохранять результаты ноутбука».
# 3. Выбрать тип сохранения Save & Run All (Commit).
# 4. Нажать кнопку Save.
